# %%
import pandas as pd 
import numpy as np

# %%
data_file = "../processed_data/all_data.csv"
dat = pd.read_csv(data_file)

# %%
dat.head()
# Out:
#      LastName  FirstName Gender Country             Date    Competition  \
# 0       abdul       hadi      w     MAS  sun 25 jul 2021  Olympic Games
# 1       abdul       hadi      w     MAS  sun 25 jul 2021  Olympic Games
# 2       abdul       hadi      w     MAS  sun 25 jul 2021  Olympic Games
# 3       abdul       hadi      w     MAS  sun 25 jul 2021  Olympic Games
# 4  abdul hadi  farah ann      w     MAS     25 july 2021  Olympic Games
#
#     Round      Location Apparatus  Rank  D_Score  E_Score  Penalty   Score  \
# 0  AAqual  Tokyo, Japan        BB  76.0      4.8    6.766      NaN  11.566
# 1  AAqual  Tokyo, Japan        FX  64.0      4.6    7.633      NaN  12.233
# 2  AAqual  Tokyo, Japan        UE  74.0      5.1    6.500      NaN  11.600
# 3  AAqual  Tokyo, Japan        VT  72.0      4.6    8.566      NaN  13.166
# 4    qual  Tokyo, Japan        BB  76.0      4.8    6.766      NaN  11.566
#
#      DateTime          Format Competition            Competitor  DateRank  \
# 0  2021-07-25  2021 - Olympic Games Japan  farah ann abdul hadi       0.0
# 1  2021-07-25  2021 - Olympic Games Japan  farah ann abdul hadi       0.0
# 2  2021-07-25  2021 - Olympic Games Japan  farah ann abdul hadi       0.0
# 3  2021-07-25  2021 - Olympic Games Japan  farah ann abdul hadi       0.0
# 4  2021-07-25  2021 - Olympic Games Japan  farah ann abdul hadi       0.0
#
#    IndividualDateRank
# 0                 1.0
# 1                 1.0
# 2                 1.0
# 3                 1.0
# 4                 1.0

# %%
class athlete:
    def __init__(self, Competitor, Gender, Country, IndividualDateRank, value):
        self.Competitor = Competitor
        self.Gender = Gender
        self.Country = Country
        self.IndividualDateRank = IndividualDateRank
        self.value = value

    def __str__(self):
        return "{}".format(self.Competitor)
    
    def __str__(self):
        return str(self.Competitor)

class team:
    def __init__(self, country:str):
        self.country = country 
        self.team = []

    def select_team(self, num_members=4):
        self.team = sorted(self.team, key=lambda athlete: athlete.value, reverse=True)
        if len(self.team) >= num_members:
            self.team = self.team[:num_members] # pick the top 4 members
        else: self.team = self.team[0]

    def new_member(self, member:athlete):
        self.team.append(member)

    def __str__(self):
        return "{}".format(self.team)
    
    def __len__(self):
        return len(self.team)

# %%
men_events = {"VT", "VT1", "VT2", "SR", "PH", "PB", "HB"}
women_events = {"BB", "VT", "VT1", "VT2", "FX", "UB"}

# %%
def get_value(competitor, data, events):
    dat = data.loc[data["Competitor"] == competitor]
    mean_scores = np.zeros(len(events))
    i = 0
    for event in events: 
        # if athlete competes on given event, add to mean score
        if len(dat.loc[dat["Apparatus"] == event]) > 0: mean_scores[i] = dat.loc[dat["Apparatus"] == event, "Score"].mean()
        else: mean_scores[i] = 0
        i += 1
    return np.mean(mean_scores)

# %%
def pick_bench_teams(gender:str, events:set, dat:pd.DataFrame):
    teams = []
    for country in list(dat["Country"].unique()):
        # print(country)
        if country == "USA": continue
        new_team = team(country=country)
        for athl in list(dat.loc[dat["Country"] == country, "Competitor"].unique()):
            # print("\t",athl)
            score = get_value(athl, dat, events)
            # print("\t", score)
            indiv_date_rank = dat.loc[(dat["Country"] == country) & (dat["Competitor"] == athl), "IndividualDateRank"].max() + 1
            new_team.new_member(athlete(Competitor=athl, Gender=gender, Country=country, IndividualDateRank=indiv_date_rank, value=score))
        new_team.select_team()
        teams.append(new_team)
    return teams

w_benchmark_teams = pick_bench_teams("w", women_events, dat.loc[dat["Gender"] == "w"])
m_benchmark_teams = pick_bench_teams("m", men_events, dat.loc[dat["Gender"] == "m"])

# %%
dat.loc[(dat["Country"] == "MAS") & (dat["Gender"] == "w"), "Competitor"].unique()
# Out:
# array(['farah ann abdul hadi', 'zarith imaan khalid', 'li wen yeoh',
#        'tan ing yueh'], dtype=object)

# %%
for i in range(10):
    print("Country={} \n".format(w_benchmark_teams[i].country))
    for j in range(len(w_benchmark_teams[i].team)):
        print(w_benchmark_teams[i].team[j])
    print("\n")
# Out:
# Country=MAS
#
# zarith imaan khalid
# farah ann abdul hadi
# tan ing yueh
# rachel yeoh li wen
#
#
# Country=SWE
#
# tonya paulsson
# jennifer williams
# nathalie westlund
# emelie westlund
#
#
# Country=ROC
#
# liliia akhaimova
# anastasiia iliankova
# angelina melnikova
# viktoria listunova
#
#
# Country=CRC
#
# franciny morales
# anelena rodriguez johanning
# anelena rodriguez
# rachel rodriguez
#
#
# Country=BRA
#
# rebeca andrade
# flavia saraiva
# jade barbosa
# carolyne pedro
#
#
# Country=JPN
#
# mai murakami
# shoko miyata
# ayaka sakaguchi
# rina kishi
#
#
# Country=ESP
#
# alba petisco
# laura casabuena
# lorena medina
# maia llacer sirera
#
#
# Country=CAN
#
# elsabeth black
# shallon olsen
# emma spence
# denelle pedrick
#
#
# Country=FRA
#
# aline friess
# morgane osyssek reimer
# mélanie de jesus dos santos
# carolann heduit
#
#
# Country=BEL
#
# lisa vaelen
# maellyse brassart
# jutta verkest
# nina derwael

# %%
import itertools

# List of objects
objects = ['a', 'b', 'c', 'd']

# Length of combinations
length = 2

# Generate combinations
combinations = list(itertools.combinations(objects, length))

# Print combinations
for combination in combinations:
    print(combination)
# Out:
# ('a', 'b')
# ('a', 'c')
# ('a', 'd')
# ('b', 'c')
# ('b', 'd')
# ('c', 'd')

# %%
objects2 = ["x", "k", "y", "z"]
length2 = 2
combs = list(itertools.combinations(objects2, length2))
combs = combs + combinations
for comb in combs: print(comb)
# Out:
# ('x', 'k')
# ('x', 'y')
# ('x', 'z')
# ('k', 'y')
# ('k', 'z')
# ('y', 'z')
# ('a', 'b')
# ('a', 'c')
# ('a', 'd')
# ('b', 'c')
# ('b', 'd')
# ('c', 'd')

# %%
from itertools import combinations
class US_team_combs:
    '''
    function for holding all team combinations to test - use like an iterable object

    main function is `generate_all_combinations`
    '''
    def __init__(self):
        self.index = 0
        # a list of team objects - each has a tuple of athlete objects
        self.team_combs = []

    def generate_all_combinations(self, gender:str, new_dat:pd.DataFrame, events:set, country:str = "USA"):
        '''
        new_dat should be the base data
        '''
        # event_vals = dict()
        # for item in list(new_dat["Apparatus"].unique()): 
        #     event_vals[item] = []
        #     for athl in list(new_dat["Competitor"].unique()): 
        #         score = new_dat.loc[(new_dat["Competitor"] == athl) & (new_dat["Apparatus"] == item), "Score"].mean()
        #         indiv_date_rank = dat.loc[(dat["Country"] == country) & (dat["Competitor"] == athl), "IndividualDateRank"].max() + 1
        #         profile = athlete(athl, gender, country, indiv_date_rank, score)
        #         event_vals[item].append(profile)
        #         # print(profile)
        # for event in event_vals:
        #     event_vals[event] = sorted(event_vals[event], key=lambda ath: ath.value)
        #     # try the top 7 scorers from each event
        #     event_vals[event] = event_vals[event][:7]
        #     event_vals[event] = [i.Competitor for i in event_vals[event]]
        # # handling top scorers in multiple categories?
        # if 
        new_dat = new_dat.loc[new_dat["Gender"] == gender]
        base_athls = team(country)
        for athl in list(new_dat["Competitor"].unique()):
            score = get_value(athl, new_dat, events)
            individual_date_rank = new_dat.loc[(new_dat["Country"] == country) & (new_dat["Competitor"] == athl), "IndividualDateRank"].max() + 1
            base_athls.new_member(athlete(athl, gender, country, individual_date_rank, score))
        base_athls.select_team(num_members=35)
        self.team_combs = list(combinations(base_athls.team, 4))
        
    # define iterative behavior for the whole class
    def __iter__(self):
        return self
    
    def __next__(self):
        if self.index >= len(self.team_combs): raise StopIteration
        value = self.team_combs[self.index]
        self.index += 1
        return value
    

USA_team = US_team_combs().generate_all_combinations(gender="w", new_dat=dat, events=women_events, country="USA")

# %%
for i in range(3): print(USA_team.team_combs[i])
# Out:
# (<__main__.athlete object at 0x7fed52ae3af0>, <__main__.athlete object at 0x7fed52ae3df0>, <__main__.athlete object at 0x7fed52dd9b40>, <__main__.athlete object at 0x7fed53049540>)
# (<__main__.athlete object at 0x7fed52ae3af0>, <__main__.athlete object at 0x7fed52ae3df0>, <__main__.athlete object at 0x7fed52dd9b40>, <__main__.athlete object at 0x7fed52ae0070>)
# (<__main__.athlete object at 0x7fed52ae3af0>, <__main__.athlete object at 0x7fed52ae3df0>, <__main__.athlete object at 0x7fed52dd9b40>, <__main__.athlete object at 0x7fed52ae39a0>)

# %%
gender = "w"
country = "USA"
new_dat = dat.loc[(dat["Country"] == "USA") & (dat["Gender"] == gender)]

# take average over the VT, VT1, VT2 to find best performer
event_vals = dict()
for item in list(new_dat["Apparatus"].unique()): 
    event_vals[item] = []
    for athl in list(new_dat["Competitor"].unique()): 
        score = new_dat.loc[(new_dat["Competitor"] == athl) & (new_dat["Apparatus"] == item), "Score"].mean()
        athl_perf = new_dat.loc[(new_dat["Competitor"] == athl) & (new_dat["Apparatus"] == item)]
        indiv_date_rank = dat.loc[(dat["Country"] == country) & (dat["Competitor"] == athl), "IndividualDateRank"].max() + 1
        profile = athlete(athl, gender, country, indiv_date_rank, score)
        event_vals[item].append(profile)
        # print(profile)
for event in event_vals:
    event_vals[event] = sorted(event_vals[event], key=lambda ath: ath.value)
    event_vals[event] = event_vals[event][:4]
# Out:
# simone biles
# mc grace callum
# jade carey
# jordan chiles
# sunisa lee
# callum mc
# mykayla skinner
# ciena alipio
# leigh anne elliott
# sydney barros
# skye blakely
# charlotte booth
# dulcy caylor
# chloe cho
# norah christian
# adriana consoli
# kayla dicello
# amelia disidore
# gabby disidore
# skylar draser
# amari drayton
# jordis eichman
# addison fatta
# emjae frazier
# karis german
# olivia greaves
# madray johnson
# shilese jones
# katelyn jong
# levi jung-ruivivar
# avery king
